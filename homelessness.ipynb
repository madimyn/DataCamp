# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('homelessness.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'region', 'state', 'individuals', 'family_members',
#        'state_pop'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %%
df.groupby('state')['individuals'].agg(['min', 'max', 'median', 'mean', 'sum'])
# Out:
#                            min       max    median      mean       sum
# state
# Alabama                 2570.0    2570.0    2570.0    2570.0    2570.0
# Alaska                  1434.0    1434.0    1434.0    1434.0    1434.0
# Arizona                 7259.0    7259.0    7259.0    7259.0    7259.0
# Arkansas                2280.0    2280.0    2280.0    2280.0    2280.0
# California            109008.0  109008.0  109008.0  109008.0  109008.0
# Colorado                7607.0    7607.0    7607.0    7607.0    7607.0
# Connecticut             2280.0    2280.0    2280.0    2280.0    2280.0
# Delaware                 708.0     708.0     708.0     708.0     708.0
# District of Columbia    3770.0    3770.0    3770.0    3770.0    3770.0
# Florida                21443.0   21443.0   21443.0   21443.0   21443.0
# Georgia                 6943.0    6943.0    6943.0    6943.0    6943.0
# Hawaii                  4131.0    4131.0    4131.0    4131.0    4131.0
# ...

# %%
df.pivot_table(index='state', values='family_members', columns='region', fill_value=0, margins=True, aggfunc=['mean', 'median', 'sum'])
# Out:
#                                    mean                                   \
# region               East North Central East South Central  Mid-Atlantic
# state
# Alabama                             0.0             864.00      0.000000
# Alaska                              0.0               0.00      0.000000
# Arizona                             0.0               0.00      0.000000
# Arkansas                            0.0               0.00      0.000000
# California                          0.0               0.00      0.000000
# Colorado                            0.0               0.00      0.000000
# Connecticut                         0.0               0.00      0.000000
# Delaware                            0.0               0.00      0.000000
# District of Columbia                0.0               0.00      0.000000
# Florida                             0.0               0.00      0.000000
# Georgia                             0.0               0.00      0.000000
# ...

# %%
df.set_index(['region', 'state'])
# df.reset_index(drop=True)
df.sort_index(ascending=False)
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 50          50            Mountain               Wyoming        434.0
# 49          49  East North Central             Wisconsin       2740.0
# 48          48      South Atlantic         West Virginia       1021.0
# 47          47             Pacific            Washington      16424.0
# 46          46      South Atlantic              Virginia       3928.0
# 45          45         New England               Vermont        780.0
# 44          44            Mountain                  Utah       1904.0
# 43          43  West South Central                 Texas      19199.0
# 42          42  East South Central             Tennessee       6139.0
# 41          41  West North Central          South Dakota        836.0
# 40          40      South Atlantic        South Carolina       3082.0
# 39          39         New England          Rhode Island        747.0
# ...
